# %% [markdown]
# # Naveen Kumar Meena
# # UE208066

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

fuel_consumption = pd.read_csv('data.csv')
fuel_consumption
# Out:
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# ...

# %%
cdf = fuel_consumption[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB','CO2EMISSIONS']]
cdf.head(11)
# Out:
#     ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0          2.0          4                   8.5           196
# 1          2.4          4                   9.6           221
# 2          1.5          4                   5.9           136
# 3          3.5          6                  11.1           255
# 4          3.5          6                  10.6           244
# 5          3.5          6                  10.0           230
# 6          3.5          6                  10.1           232
# 7          3.7          6                  11.1           255
# 8          3.7          6                  11.6           267
# 9          2.4          4                   9.2           212
# 10         2.4          4                   9.8           225

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()

# %%
# x= fuel_consumption.drop("CO2EMISSIONS"  , axis =1)

y=fuel_consumption["CO2EMISSIONS"]
y
# Out:
# 0       196
# 1       221
# 2       136
# 3       255
# 4       244
#        ...
# 1062    271
# 1063    264
# 1064    271
# 1065    260
# 1066    294
# Name: CO2EMISSIONS, Length: 1067, dtype: int64

# %%
from sklearn.model_selection import train_test_split

train , test = train_test_split(fuel_consumption , test_size=0.2)
train
# Out:
#      MODELYEAR           MAKE                    MODEL  \
# 566       2014         JAGUAR                XKR COUPE
# 753       2014  MERCEDES-BENZ  E 63 AMG S 4MATIC WAGON
# 768       2014  MERCEDES-BENZ         S 550 4MATIC SWB
# 676       2014          LEXUS              RX 450h AWD
# 28        2014           AUDI               A7 QUATTRO
# ..         ...            ...                      ...
# 554       2014         JAGUAR                    XFR-S
# 756       2014  MERCEDES-BENZ    GL 350 BLUETEC 4MATIC
# 402       2014           FORD                FOCUS FFV
# 381       2014           FORD                 F150 FFV
# 131       2014            BMW             X5 xDRIVE50i
#
#                  VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  \
# 566               MINICOMPACT         5.0          8          AS6        Z
# 753  STATION WAGON - MID-SIZE         5.5          8          AS7        Z
# 768                 FULL-SIZE         4.7          8          AS7        Z
# ...

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['ENGINESIZE']])
train_y = np.asanyarray(train[['CO2EMISSIONS']])
regr.fit (train_x, train_y)
# Out:
# LinearRegression()

# %%
plt.scatter(train.ENGINESIZE,train.CO2EMISSIONS,color='red');
plt.plot(train_x,regr.coef_[0][0]*train_x + regr.intercept_[0]);

# %% [markdown]
# # -------Multiple LinearRegression-------

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['ENGINESIZE','CYLINDERS' , 'FUELCONSUMPTION_COMB']])
train_y = np.asanyarray(train[['CO2EMISSIONS']])
regr.fit (train_x, train_y)

print('Coefficient' ,regr.coef_)
# Out:
# Coefficient [[11.59685981  7.45939244  9.32214233]]

# %%
y_hat= regr.predict(test[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB']])
x = np.asanyarray(test[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB']])
y = np.asanyarray(test[['CO2EMISSIONS']])
print("Residual sum of squares: %.2f"
% np.mean((y_hat - y) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(x, y))
# Out:
# Residual sum of squares: 511.70
# Variance score: 0.87
# c:\users\91807\appdata\local\programs\python\python39\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %% [markdown]
# # WithOut Gredient decent --- Normal function

# %%
import numpy as np
#taking features size,floors,bedrooms
x=np.array([[1,100,2,2],[1,150,1,3],[1,125,2,3]])
y=np.array([15,13,18])

y=y.reshape((3,1))
t0,t1,t2,t3=0.3,1,0.1,0.05

#theta values
tt=np.array([t0,t1,t2,t3])

xtheta=np.multiply(tt,x)

rss=(np.sum(xtheta-y)**2)
print("error",rss)

xT = np.transpose(x)
xT


b = np.dot(xT,y)
a = np.linalg.inv(np.dot(xT,x))
theta_new = np.dot(a,b)
theta = np.array(theta_new)
theta
# Out:
# error 37171.84
# array([[-24.   ],
#        [  0.125],
#        [  6.   ],
#        [  2.   ]])

# %%
y_hat = np.dot(x,theta)
error = np.mean((y_hat - y) ** 2)
error
# Out:
# 73.15104166666667

# %% [markdown]
# # With fuel consumption

# %%
import numpy as np
#taking features size,floors,bedrooms
x = np.asanyarray(test[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB']])
y = np.asanyarray(test[['CO2EMISSIONS']])
a = y.size
y=y.reshape((a,1))
t0,t1,t2=0.3,1,0.1

#theta values
tt=np.array([t0,t1,t2])

xtheta=np.multiply(tt,x)

rss=(np.sum(xtheta-y)**2)
print("error",rss)

xT = np.transpose(x)
xT


b = np.dot(xT,y)
a = np.linalg.inv(np.dot(xT,x))
theta_new = np.dot(a,b)
theta = np.array(theta_new)
theta
# Out:
# error 25999072859.5984
# array([[-9.11984695],
#        [19.00833758],
#        [15.13496578]])

# %%
y_hat = np.dot(x,theta)

# %%
error = np.mean((y_hat - y) ** 2)
error
# Out:
# 686.8021283876876
