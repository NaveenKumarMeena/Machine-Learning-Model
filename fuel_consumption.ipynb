# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

fuel_consumption = pd.read_csv('data.csv')
fuel_consumption
# Out:
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# ...

# %%
cdf = fuel_consumption[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB','CO2EMISSIONS']]
cdf.head(11)
# Out:
#     ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0          2.0          4                   8.5           196
# 1          2.4          4                   9.6           221
# 2          1.5          4                   5.9           136
# 3          3.5          6                  11.1           255
# 4          3.5          6                  10.6           244
# 5          3.5          6                  10.0           230
# 6          3.5          6                  10.1           232
# 7          3.7          6                  11.1           255
# 8          3.7          6                  11.6           267
# 9          2.4          4                   9.2           212
# 10         2.4          4                   9.8           225

# %%
from sklearn.ensemble import linear_model
regr = linear_model.LinearRegression()

# %%
# x= fuel_consumption.drop("CO2EMISSIONS"  , axis =1)

y=fuel_consumption["CO2EMISSIONS"]
y
# Out:
# 0       196
# 1       221
# 2       136
# 3       255
# 4       244
#        ...
# 1062    271
# 1063    264
# 1064    271
# 1065    260
# 1066    294
# Name: CO2EMISSIONS, Length: 1067, dtype: int64

# %%
from sklearn.model_selection import train_test_split

train , test = train_test_split(fuel_consumption , test_size=0.2)
train
# Out:
#      MODELYEAR           MAKE               MODEL             VEHICLECLASS  \
# 139       2014            BMW       Z4 sDRIVE35is               TWO-SEATER
# 923       2014    ROLLS-ROYCE           GHOST EWB                FULL-SIZE
# 545       2014       INFINITI            QX70 AWD              SUV - SMALL
# 851       2014         NISSAN          PATHFINDER              SUV - SMALL
# 271       2014      CHEVROLET                TRAX              SUV - SMALL
# ..         ...            ...                 ...                      ...
# 429       2014           FORD     TRANSIT CONNECT  SPECIAL PURPOSE VEHICLE
# 906       2014        PORSCHE          PANAMERA S                FULL-SIZE
# 331       2014          DODGE         JOURNEY FFV              SUV - SMALL
# 726       2014  MERCEDES-BENZ               C 350                  COMPACT
# 512       2014        HYUNDAI  SANTA FE SPORT 4WD              SUV - SMALL
#
# ...

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['ENGINESIZE']])
train_y = np.asanyarray(train[['CO2EMISSIONS']])
regr.fit (train_x, train_y)
# Out:
# LinearRegression()

# %%
plt.scatter(train.ENGINESIZE,train.CO2EMISSIONS,color='red');
plt.plot(train_x,regr.coef_[0][0]*train_x + regr.intercept_[0]);

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_z = np.asanyarray(train[['CYLINDERS']])
train_y = np.asanyarray(train[['CO2EMISSIONS']])
regr.fit (train_z, train_y)
# Out:
# LinearRegression()

# %%
plt.scatter(train.CYLINDERS,train.CO2EMISSIONS,color='red');
plt.plot(train_z,regr.coef_[0][0]*train_z + regr.intercept_[0]);

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_w = np.asanyarray(train[['FUELCONSUMPTION_COMB']])
train_y = np.asanyarray(train[['CO2EMISSIONS']])
regr.fit (train_w, train_y)
# Out:
# LinearRegression()

# %%
plt.scatter(train.FUELCONSUMPTION_COMB,train.CO2EMISSIONS,color='red');
plt.plot(train_w,regr.coef_[0][0]*train_w + regr.intercept_[0]);

# %%
plt.scatter(train.ENGINESIZE,train.CO2EMISSIONS,color='red');
plt.plot(train_x,regr.coef_[0][0]*train_x + regr.intercept_[0],color= 'yellow');
plt.scatter(train.CYLINDERS,train.CO2EMISSIONS,color='blue');
plt.plot(train_z,regr.coef_[0][0]*train_z + regr.intercept_[0],color = 'orange');
plt.scatter(train.FUELCONSUMPTION_COMB,train.CO2EMISSIONS,color='green');
plt.plot(train_w,regr.coef_[0][0]*train_w + regr.intercept_[0],color='black');
